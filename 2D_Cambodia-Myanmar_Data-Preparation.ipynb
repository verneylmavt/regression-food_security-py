# %%
# Import Library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Read the CSV file online
df_gdp_url = "https://raw.githubusercontent.com/verneylmavt/2D_Project_Term-3/main/2D_Data-Set_All-Country_GDP.csv"
df_gdp = pd.read_csv(df_gdp_url)
df_gdp = df_gdp.set_index("Country Name")
display(df_gdp)
# Out:
#                             Country Code                Indicator Name  \
# Country Name
# Aruba                                ABW  GDP per capita (current US$)
# Africa Eastern and Southern          AFE  GDP per capita (current US$)
# Afghanistan                          AFG  GDP per capita (current US$)
# Africa Western and Central           AFW  GDP per capita (current US$)
# Angola                               AGO  GDP per capita (current US$)
# ...                                  ...                           ...
# Kosovo                               XKX  GDP per capita (current US$)
# Yemen, Rep.                          YEM  GDP per capita (current US$)
# South Africa                         ZAF  GDP per capita (current US$)
# Zambia                               ZMB  GDP per capita (current US$)
# Zimbabwe                             ZWE  GDP per capita (current US$)
#
#                              Indicator Code        1960        1961  \
# Country Name
# Aruba                        NY.GDP.PCAP.CD         NaN         NaN
# Africa Eastern and Southern  NY.GDP.PCAP.CD  162.726326  162.555968
# Afghanistan                  NY.GDP.PCAP.CD   59.773234   59.860900
# Africa Western and Central   NY.GDP.PCAP.CD  107.930722  113.080062
# Angola                       NY.GDP.PCAP.CD         NaN         NaN
# ...                                     ...         ...         ...
# Kosovo                       NY.GDP.PCAP.CD         NaN         NaN
# Yemen, Rep.                  NY.GDP.PCAP.CD         NaN         NaN
# South Africa                 NY.GDP.PCAP.CD  511.618737  526.461750
# Zambia                       NY.GDP.PCAP.CD  232.188565  220.042067
# Zimbabwe                     NY.GDP.PCAP.CD  278.813847  280.828663
#
#                                    1962        1963        1964        1965  \
# Country Name
# Aruba                               NaN         NaN         NaN         NaN
# Africa Eastern and Southern  172.271022  199.784916  180.228774  199.517227
# Afghanistan                   58.458009   78.706429   82.095307  101.108325
# Africa Western and Central   118.829461  123.441090  131.852423  138.524029
# Angola                              NaN         NaN         NaN         NaN
# ...                                 ...         ...         ...         ...
# Kosovo                              NaN         NaN         NaN         NaN
# Yemen, Rep.                         NaN         NaN         NaN         NaN
# South Africa                 546.261935  589.160460  632.716104  674.186433
# Zambia                       212.578449  213.896759  242.384472  303.281741
# Zimbabwe                     276.688233  277.479715  281.558896  293.308788
#
#                                    1966  ...          2012          2013  \
# Country Name                             ...
# Aruba                               NaN  ...  25496.843940  26442.426800
# Africa Eastern and Southern  211.054388  ...   1777.303950   1748.905594
# Afghanistan                  137.594298  ...    638.845852    624.315454
# Africa Western and Central   144.323882  ...   1965.115750   2157.494584
# Angola                              NaN  ...   4978.434435   5127.717243
# ...                                 ...  ...           ...           ...
# Kosovo                              NaN  ...   3410.859780   3704.784221
# Yemen, Rep.                         NaN  ...   1446.536472   1607.152173
# South Africa                 714.562010  ...   8222.197279   7467.079185
# Zambia                       343.373670  ...   1763.069442   1878.346811
# Zimbabwe                     277.234532  ...   1304.968011   1429.998461
#
#                                      2014          2015          2016  \
# Country Name
# Aruba                        26895.057170  28399.050130  28453.715560
# Africa Eastern and Southern   1736.242220   1556.316469   1446.533624
# Afghanistan                    614.223342    556.007221    512.012778
# Africa Western and Central    2212.914095   1894.322115   1673.843681
# Angola                        5094.112329   3127.890598   1728.023754
# ...                                   ...           ...           ...
# Kosovo                        3902.676013   3520.766449   3759.560246
# Yemen, Rep.                   1674.002572   1601.807163   1152.738019
# South Africa                  6988.808739   6259.839681   5756.965741
# Zambia                        1762.427817   1338.290927   1280.806543
# Zimbabwe                      1434.896277   1445.069702   1464.588957
#
#                                      2017          2018          2019  \
# Country Name
# Aruba                        29348.418970  30253.714230  31135.884360
# Africa Eastern and Southern   1629.404273   1541.031661   1511.309259
# Afghanistan                    516.679862    485.668419    494.179350
# Africa Western and Central    1613.490478   1704.135698   1777.852822
# Angola                        2313.220584   2524.942483   2177.799015
# ...                                   ...           ...           ...
# Kosovo                        4009.380987   4384.048892   4416.108358
# Yemen, Rep.                    964.340344    758.145949    750.554583
# South Africa                  6690.939847   7005.095413   6624.761865
# Zambia                        1535.196574   1516.368371   1305.001031
# Zimbabwe                      1235.189032   1254.642265   1316.740657
#
#                                      2020         2021
# Country Name
# Aruba                        23384.298790          NaN
# Africa Eastern and Southern   1360.878645  1557.722682
# Afghanistan                    516.747871          NaN
# Africa Western and Central    1709.764129  1774.921218
# Angola                        1631.431691  2137.909393
# ...                                   ...          ...
# Kosovo                        4310.811183  4986.582469
# Yemen, Rep.                    631.681490   690.759273
# South Africa                  5655.867654  6994.211654
# Zambia                         985.132436  1120.630171
# Zimbabwe                      1214.509820  1737.173977
#
# [266 rows x 65 columns]

# %%
df_gdp_cambodia_myanmar = (df_gdp.loc[["Cambodia", "Myanmar"], "2001":"2020"]).copy()
display(df_gdp_cambodia_myanmar)
# Out:
#                     2001        2002        2003        2004        2005  \
# Country Name
# Cambodia      321.150224  338.987477  362.335482  408.513639  474.111192
# Myanmar       131.715298  128.099702  161.055524  193.368766  216.311501
#
#                     2006        2007        2008        2009        2010  \
# Country Name
# Cambodia      539.750329  631.525258  745.609127  738.054731  785.502667
# Myanmar       240.624014  314.202294  460.908889  586.168180  746.945360
#
#                      2011         2012         2013         2014         2015  \
# Country Name
# Cambodia       882.275614   950.880346  1013.420536  1093.495976  1162.904995
# Myanmar       1061.344429  1134.302224  1168.165453  1210.097654  1196.743333
#
#                      2016         2017         2018         2019         2020
# Country Name
# Cambodia      1269.591499  1385.260066  1512.126989  1643.121389  1547.511388
# Myanmar       1136.610627  1151.114464  1250.173685  1271.111536  1450.662673

# %%
print(list(df_gdp_cambodia_myanmar.columns))
# Out:
# ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
cambodia_gdp = np.array(df_gdp_cambodia_myanmar.loc["Cambodia", "2001":"2020"])
print(cambodia_gdp)
myanmar_gdp = np.array(df_gdp_cambodia_myanmar.loc["Myanmar", "2001":"2020"])
print(myanmar_gdp)
# Out:
# [ 321.1502236  338.9874773  362.3354822  408.5136388  474.1111921
#   539.7503289  631.5252576  745.609127   738.0547312  785.5026671
#   882.275614   950.880346  1013.420536  1093.495976  1162.904995
#  1269.591499  1385.260066  1512.126989  1643.121389  1547.511388 ]
# [ 131.7152982  128.0997018  161.0555236  193.3687658  216.3115014
#   240.6240142  314.2022942  460.9088892  586.1681802  746.94536
#  1061.344429  1134.302224  1168.165453  1210.097654  1196.743333
#  1136.610627  1151.114464  1250.173685  1271.111536  1450.662673 ]

# %%
# Read the CSV file online
df_inflation_rate_url = "https://raw.githubusercontent.com/verneylmavt/2D_Project_Term-3/main/2D_Data-Set_All-Country_GDP.csv"
df_inflation_rate = pd.read_csv(df_inflation_rate_url)
df_inflation_rate = df_inflation_rate.set_index("Country Name")
display(df_inflation_rate)
# Out:
#                             Country Code                Indicator Name  \
# Country Name
# Aruba                                ABW  GDP per capita (current US$)
# Africa Eastern and Southern          AFE  GDP per capita (current US$)
# Afghanistan                          AFG  GDP per capita (current US$)
# Africa Western and Central           AFW  GDP per capita (current US$)
# Angola                               AGO  GDP per capita (current US$)
# ...                                  ...                           ...
# Kosovo                               XKX  GDP per capita (current US$)
# Yemen, Rep.                          YEM  GDP per capita (current US$)
# South Africa                         ZAF  GDP per capita (current US$)
# Zambia                               ZMB  GDP per capita (current US$)
# Zimbabwe                             ZWE  GDP per capita (current US$)
#
#                              Indicator Code        1960        1961  \
# Country Name
# Aruba                        NY.GDP.PCAP.CD         NaN         NaN
# Africa Eastern and Southern  NY.GDP.PCAP.CD  162.726326  162.555968
# Afghanistan                  NY.GDP.PCAP.CD   59.773234   59.860900
# Africa Western and Central   NY.GDP.PCAP.CD  107.930722  113.080062
# Angola                       NY.GDP.PCAP.CD         NaN         NaN
# ...                                     ...         ...         ...
# Kosovo                       NY.GDP.PCAP.CD         NaN         NaN
# Yemen, Rep.                  NY.GDP.PCAP.CD         NaN         NaN
# South Africa                 NY.GDP.PCAP.CD  511.618737  526.461750
# Zambia                       NY.GDP.PCAP.CD  232.188565  220.042067
# Zimbabwe                     NY.GDP.PCAP.CD  278.813847  280.828663
#
#                                    1962        1963        1964        1965  \
# Country Name
# Aruba                               NaN         NaN         NaN         NaN
# Africa Eastern and Southern  172.271022  199.784916  180.228774  199.517227
# Afghanistan                   58.458009   78.706429   82.095307  101.108325
# Africa Western and Central   118.829461  123.441090  131.852423  138.524029
# Angola                              NaN         NaN         NaN         NaN
# ...                                 ...         ...         ...         ...
# Kosovo                              NaN         NaN         NaN         NaN
# Yemen, Rep.                         NaN         NaN         NaN         NaN
# South Africa                 546.261935  589.160460  632.716104  674.186433
# Zambia                       212.578449  213.896759  242.384472  303.281741
# Zimbabwe                     276.688233  277.479715  281.558896  293.308788
#
#                                    1966  ...          2012          2013  \
# Country Name                             ...
# Aruba                               NaN  ...  25496.843940  26442.426800
# Africa Eastern and Southern  211.054388  ...   1777.303950   1748.905594
# Afghanistan                  137.594298  ...    638.845852    624.315454
# Africa Western and Central   144.323882  ...   1965.115750   2157.494584
# Angola                              NaN  ...   4978.434435   5127.717243
# ...                                 ...  ...           ...           ...
# Kosovo                              NaN  ...   3410.859780   3704.784221
# Yemen, Rep.                         NaN  ...   1446.536472   1607.152173
# South Africa                 714.562010  ...   8222.197279   7467.079185
# Zambia                       343.373670  ...   1763.069442   1878.346811
# Zimbabwe                     277.234532  ...   1304.968011   1429.998461
#
#                                      2014          2015          2016  \
# Country Name
# Aruba                        26895.057170  28399.050130  28453.715560
# Africa Eastern and Southern   1736.242220   1556.316469   1446.533624
# Afghanistan                    614.223342    556.007221    512.012778
# Africa Western and Central    2212.914095   1894.322115   1673.843681
# Angola                        5094.112329   3127.890598   1728.023754
# ...                                   ...           ...           ...
# Kosovo                        3902.676013   3520.766449   3759.560246
# Yemen, Rep.                   1674.002572   1601.807163   1152.738019
# South Africa                  6988.808739   6259.839681   5756.965741
# Zambia                        1762.427817   1338.290927   1280.806543
# Zimbabwe                      1434.896277   1445.069702   1464.588957
#
#                                      2017          2018          2019  \
# Country Name
# Aruba                        29348.418970  30253.714230  31135.884360
# Africa Eastern and Southern   1629.404273   1541.031661   1511.309259
# Afghanistan                    516.679862    485.668419    494.179350
# Africa Western and Central    1613.490478   1704.135698   1777.852822
# Angola                        2313.220584   2524.942483   2177.799015
# ...                                   ...           ...           ...
# Kosovo                        4009.380987   4384.048892   4416.108358
# Yemen, Rep.                    964.340344    758.145949    750.554583
# South Africa                  6690.939847   7005.095413   6624.761865
# Zambia                        1535.196574   1516.368371   1305.001031
# Zimbabwe                      1235.189032   1254.642265   1316.740657
#
#                                      2020         2021
# Country Name
# Aruba                        23384.298790          NaN
# Africa Eastern and Southern   1360.878645  1557.722682
# Afghanistan                    516.747871          NaN
# Africa Western and Central    1709.764129  1774.921218
# Angola                        1631.431691  2137.909393
# ...                                   ...          ...
# Kosovo                        4310.811183  4986.582469
# Yemen, Rep.                    631.681490   690.759273
# South Africa                  5655.867654  6994.211654
# Zambia                         985.132436  1120.630171
# Zimbabwe                      1214.509820  1737.173977
#
# [266 rows x 65 columns]

# %%
df_inflation_rate_cambodia_myanmar = (df_inflation_rate.loc[["Cambodia", "Myanmar"], "2001":"2020"]).copy()
display(df_inflation_rate_cambodia_myanmar)
# Out:
#                     2001        2002        2003        2004        2005  \
# Country Name
# Cambodia      321.150224  338.987477  362.335482  408.513639  474.111192
# Myanmar       131.715298  128.099702  161.055524  193.368766  216.311501
#
#                     2006        2007        2008        2009        2010  \
# Country Name
# Cambodia      539.750329  631.525258  745.609127  738.054731  785.502667
# Myanmar       240.624014  314.202294  460.908889  586.168180  746.945360
#
#                      2011         2012         2013         2014         2015  \
# Country Name
# Cambodia       882.275614   950.880346  1013.420536  1093.495976  1162.904995
# Myanmar       1061.344429  1134.302224  1168.165453  1210.097654  1196.743333
#
#                      2016         2017         2018         2019         2020
# Country Name
# Cambodia      1269.591499  1385.260066  1512.126989  1643.121389  1547.511388
# Myanmar       1136.610627  1151.114464  1250.173685  1271.111536  1450.662673

# %%
print(list(df_inflation_rate_cambodia_myanmar.columns))
# Out:
# ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
cambodia_inflation_rate = np.array(df_inflation_rate_cambodia_myanmar.loc["Cambodia", "2001":"2020"])
print(cambodia_inflation_rate)
myanmar_inflation_rate = np.array(df_inflation_rate_cambodia_myanmar.loc["Myanmar", "2001":"2020"])
print(myanmar_inflation_rate)
# Out:
# [ 321.1502236  338.9874773  362.3354822  408.5136388  474.1111921
#   539.7503289  631.5252576  745.609127   738.0547312  785.5026671
#   882.275614   950.880346  1013.420536  1093.495976  1162.904995
#  1269.591499  1385.260066  1512.126989  1643.121389  1547.511388 ]
# [ 131.7152982  128.0997018  161.0555236  193.3687658  216.3115014
#   240.6240142  314.2022942  460.9088892  586.1681802  746.94536
#  1061.344429  1134.302224  1168.165453  1210.097654  1196.743333
#  1136.610627  1151.114464  1250.173685  1271.111536  1450.662673 ]

# %%
# Read the CSV file online
df_pin1416_url = "https://raw.githubusercontent.com/verneylmavt/2D_Project_Term-3/main/2D_Data-Set_All-Country_Gross-per-capita-Production-Index-Number-(2014-2016%20%3D%20100)_AVERAGE.csv"
df_pin1416 = pd.read_csv(df_pin1416_url, encoding='latin-1')
df_pin1416 = df_pin1416.set_index("Area")
display(df_pin1416)
# Out:
#             ï»¿Domain Code              Domain  Area Code (M49)  Element Code  \
# Area
# Afghanistan             QI  Production Indices                4           434
# Afghanistan             QI  Production Indices                4           434
# Afghanistan             QI  Production Indices                4           434
# Afghanistan             QI  Production Indices                4           434
# Afghanistan             QI  Production Indices                4           434
# ...                    ...                 ...              ...           ...
# Zimbabwe                QI  Production Indices              716           434
# Zimbabwe                QI  Production Indices              716           434
# Zimbabwe                QI  Production Indices              716           434
# Zimbabwe                QI  Production Indices              716           434
# Zimbabwe                QI  Production Indices              716           434
#
#                                                        Element  \
# Area
# Afghanistan  Gross per capita Production Index Number (2014...
# Afghanistan  Gross per capita Production Index Number (2014...
# Afghanistan  Gross per capita Production Index Number (2014...
# Afghanistan  Gross per capita Production Index Number (2014...
# Afghanistan  Gross per capita Production Index Number (2014...
# ...                                                        ...
# Zimbabwe     Gross per capita Production Index Number (2014...
# Zimbabwe     Gross per capita Production Index Number (2014...
# Zimbabwe     Gross per capita Production Index Number (2014...
# Zimbabwe     Gross per capita Production Index Number (2014...
# Zimbabwe     Gross per capita Production Index Number (2014...
#
#             Item Code (CPC)         Item  Year Code  Year   Unit   Value Flag  \
# Area
# Afghanistan           F2051  Agriculture       1961  1961  index  161.93    E
# Afghanistan           F2051  Agriculture       1962  1962  index  161.58    E
# Afghanistan           F2051  Agriculture       1963  1963  index  159.56    E
# Afghanistan           F2051  Agriculture       1964  1964  index  166.81    E
# Afghanistan           F2051  Agriculture       1965  1965  index  170.37    E
# ...                     ...          ...        ...   ...    ...     ...  ...
# Zimbabwe              F2051  Agriculture       2016  2016  index   95.59    E
# Zimbabwe              F2051  Agriculture       2017  2017  index  100.70    E
# Zimbabwe              F2051  Agriculture       2018  2018  index  115.99    E
# Zimbabwe              F2051  Agriculture       2019  2019  index   91.59    E
# Zimbabwe              F2051  Agriculture       2020  2020  index  105.22    E
#
#             Flag Description
# Area
# Afghanistan  Estimated value
# Afghanistan  Estimated value
# Afghanistan  Estimated value
# Afghanistan  Estimated value
# Afghanistan  Estimated value
# ...                      ...
# Zimbabwe     Estimated value
# Zimbabwe     Estimated value
# Zimbabwe     Estimated value
# Zimbabwe     Estimated value
# Zimbabwe     Estimated value
#
# [10920 rows x 13 columns]

# %%
df_pin1416_cambodia_myanmar = (df_pin1416.loc[["Cambodia", "Myanmar"], :]).copy()
df_pin1416_cambodia_myanmar["Year Code"] = df_pin1416_cambodia_myanmar["Year Code"].astype('int')
df_pin1416_cambodia_myanmar = df_pin1416_cambodia_myanmar.loc[
    (df_pin1416_cambodia_myanmar["Year Code"] >= 2001) & (df_pin1416_cambodia_myanmar["Year Code"] <= 2020), :]
display(df_pin1416_cambodia_myanmar)
# Out:
#          ï»¿Domain Code              Domain  Area Code (M49)  Element Code  \
# Area
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Cambodia             QI  Production Indices              116           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
# Myanmar              QI  Production Indices              104           434
#
#                                                     Element Item Code (CPC)  \
# Area
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Cambodia  Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
# Myanmar   Gross per capita Production Index Number (2014...           F2051
#
#                  Item  Year Code  Year   Unit   Value Flag Flag Description
# Area
# Cambodia  Agriculture       2001  2001  index   52.79    E  Estimated value
# Cambodia  Agriculture       2002  2002  index   49.46    E  Estimated value
# Cambodia  Agriculture       2003  2003  index   57.65    E  Estimated value
# Cambodia  Agriculture       2004  2004  index   53.83    E  Estimated value
# Cambodia  Agriculture       2005  2005  index   68.71    E  Estimated value
# Cambodia  Agriculture       2006  2006  index   73.50    E  Estimated value
# Cambodia  Agriculture       2007  2007  index   75.90    E  Estimated value
# Cambodia  Agriculture       2008  2008  index   81.68    E  Estimated value
# Cambodia  Agriculture       2009  2009  index   84.33    E  Estimated value
# Cambodia  Agriculture       2010  2010  index   89.31    E  Estimated value
# Cambodia  Agriculture       2011  2011  index  100.67    E  Estimated value
# Cambodia  Agriculture       2012  2012  index  102.56    E  Estimated value
# Cambodia  Agriculture       2013  2013  index  102.11    E  Estimated value
# Cambodia  Agriculture       2014  2014  index   99.42    E  Estimated value
# Cambodia  Agriculture       2015  2015  index   98.42    E  Estimated value
# Cambodia  Agriculture       2016  2016  index  102.17    E  Estimated value
# Cambodia  Agriculture       2017  2017  index  105.05    E  Estimated value
# Cambodia  Agriculture       2018  2018  index  106.81    E  Estimated value
# Cambodia  Agriculture       2019  2019  index  106.21    E  Estimated value
# Cambodia  Agriculture       2020  2020  index  103.61    E  Estimated value
# Myanmar   Agriculture       2001  2001  index   59.21    E  Estimated value
# Myanmar   Agriculture       2002  2002  index   60.64    E  Estimated value
# Myanmar   Agriculture       2003  2003  index   65.22    E  Estimated value
# Myanmar   Agriculture       2004  2004  index   69.95    E  Estimated value
# Myanmar   Agriculture       2005  2005  index   77.51    E  Estimated value
# Myanmar   Agriculture       2006  2006  index   86.08    E  Estimated value
# Myanmar   Agriculture       2007  2007  index   90.42    E  Estimated value
# Myanmar   Agriculture       2008  2008  index   96.56    E  Estimated value
# Myanmar   Agriculture       2009  2009  index  100.13    E  Estimated value
# Myanmar   Agriculture       2010  2010  index  102.32    E  Estimated value
# Myanmar   Agriculture       2011  2011  index   97.60    E  Estimated value
# Myanmar   Agriculture       2012  2012  index   95.65    E  Estimated value
# Myanmar   Agriculture       2013  2013  index   99.23    E  Estimated value
# Myanmar   Agriculture       2014  2014  index   98.77    E  Estimated value
# Myanmar   Agriculture       2015  2015  index  101.00    E  Estimated value
# Myanmar   Agriculture       2016  2016  index  100.22    E  Estimated value
# Myanmar   Agriculture       2017  2017  index   99.96    E  Estimated value
# Myanmar   Agriculture       2018  2018  index  101.29    E  Estimated value
# Myanmar   Agriculture       2019  2019  index  100.82    E  Estimated value
# Myanmar   Agriculture       2020  2020  index   99.54    E  Estimated value

# %%
cambodia_pin1416 = np.array(df_pin1416_cambodia_myanmar.loc["Cambodia", "Value"])
print(cambodia_pin1416)

myanmar_pin1416 = np.array(df_pin1416_cambodia_myanmar.loc["Myanmar", "Value"])
print(myanmar_pin1416)
# Out:
# [ 52.79  49.46  57.65  53.83  68.71  73.5   75.9   81.68  84.33  89.31
#  100.67 102.56 102.11  99.42  98.42 102.17 105.05 106.81 106.21 103.61]
# [ 59.21  60.64  65.22  69.95  77.51  86.08  90.42  96.56 100.13 102.32
#   97.6   95.65  99.23  98.77 101.   100.22  99.96 101.29 100.82  99.54]

# %%
print(df_pin1416_cambodia_myanmar.loc[:, "Year Code"].tolist())
# Out:
# [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
df = pd.DataFrame()
df["Country Name"] = pd.concat([pd.DataFrame(np.full((20,), "Cambodia")), pd.DataFrame(np.full((20,), "Myanmar"))], ignore_index=True)
df["Year"] = df_pin1416_cambodia_myanmar.loc[:, "Year Code"].tolist()
df["Percentage of Undernourishment Prevalence (3-Year Average)"] =
df["Binary Categorical"] = pd.concat([pd.DataFrame(np.full((20,), 0)), pd.DataFrame(np.full((20,), 1))], ignore_index=True)
df["GDP per Capita (USD)"] = cambodia_gdp + myanmar_gdp
df["Annual Inflation Rate (%)"] = cambodia_inflation_rate + myanmar_inflation_rate
df["Gross per capita Production Index Number (2014-2016 = 100)"] = cambodia_pin1416 + myanmar_pin1416
display(df)
# Out:
#    Country Name  Year
# 0      Cambodia  2001
# 1      Cambodia  2002
# 2      Cambodia  2003
# 3      Cambodia  2004
# 4      Cambodia  2005
# 5      Cambodia  2006
# 6      Cambodia  2007
# 7      Cambodia  2008
# 8      Cambodia  2009
# 9      Cambodia  2010
# 10     Cambodia  2011
# 11     Cambodia  2012
# 12     Cambodia  2013
# 13     Cambodia  2014
# 14     Cambodia  2015
# 15     Cambodia  2016
# 16     Cambodia  2017
# 17     Cambodia  2018
# 18     Cambodia  2019
# 19     Cambodia  2020
# 20      Myanmar  2001
# 21      Myanmar  2002
# 22      Myanmar  2003
# 23      Myanmar  2004
# 24      Myanmar  2005
# 25      Myanmar  2006
# 26      Myanmar  2007
# 27      Myanmar  2008
# 28      Myanmar  2009
# 29      Myanmar  2010
# 30      Myanmar  2011
# 31      Myanmar  2012
# 32      Myanmar  2013
# 33      Myanmar  2014
# 34      Myanmar  2015
# 35      Myanmar  2016
# 36      Myanmar  2017
# 37      Myanmar  2018
# 38      Myanmar  2019
# 39      Myanmar  2020
